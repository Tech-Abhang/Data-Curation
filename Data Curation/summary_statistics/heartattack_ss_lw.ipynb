# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("anxiety_attack_dataset.csv")

# %%
data.head()
# Out:
#    ID  Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0   1   56  Female      Other          9.6                           8.3
# 1   2   46    Male    Teacher          6.4                           7.3
# 2   3   32  Female     Doctor          6.9                           1.0
# 3   4   60    Male     Doctor          9.2                           3.7
# 4   5   25    Male    Student          9.2                           2.5
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                       175                                  6      No
# 1                        97                                  6      No
# 2                       467                                 14      No
# 3                       471                                 16      No
# 4                       364                                  2      No
#
#   Family History of Anxiety  Stress Level (1-10)  \
# ...

# %% [markdown]
# this prints the top 5 rows of the table.

# %%
data.describe()
# Out:
#                 ID          Age   Sleep Hours  Physical Activity (hrs/week)  \
# count  12000.00000  12000.00000  12000.000000                  12000.000000
# mean    6000.50000     40.96675      6.482650                      5.030892
# std     3464.24595     13.47328      2.014885                      2.889000
# min        1.00000     18.00000      3.000000                      0.000000
# 25%     3000.75000     29.00000      4.800000                      2.500000
# 50%     6000.50000     41.00000      6.500000                      5.000000
# 75%     9000.25000     53.00000      8.200000                      7.525000
# max    12000.00000     64.00000     10.000000                     10.000000
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week)  \
# count              12000.000000                       12000.000000
# mean                 246.696083                           9.492833
# std                  144.487071                           5.769364
# ...

# %% [markdown]
# this gives detailed info about the table.

# %%
data["Sleep Hours"].mean()
# Out:
# 6.4826500000000005

# %% [markdown]
# this shows the avg hours of sleep taken by heart patients.

# %%
data["Age"].median()
# Out:
# 41.0

# %% [markdown]
# this shows the median age.

# %%
data["Age"].mode()
# Out:
# 0    43
# Name: Age, dtype: int64

# %% [markdown]
# this shows the mode add.

# %%
data.groupby("Gender")["Age"].mean()
# Out:
# Gender
# Female    41.005681
# Male      40.948454
# Other     40.707265
# Name: Age, dtype: float64

# %% [markdown]
# we get the avg age for heart attack patients with respect to age.

# %%
smoking_counts=data["Smoking"].value_counts()

# %%
smoking_yes_count = smoking_counts.get('Yes', 0)
print(f"Number of people smoking: {smoking_yes_count}")
# Out:
# Number of people smoking: 3583

# %% [markdown]
# this give the number of people smoking

# %% [markdown]
# this gives total size of data

# %%
print(smoking_counts)
# Out:
# Smoking
# No     8417
# Yes    3583
# Name: count, dtype: int64

# %% [markdown]
# this give how many people are smoking in the data.

# %%
smoking_to_severity = data.groupby("Smoking")["Severity of Anxiety Attack (1-10)"].mean()
print(smoking_to_severity)
# Out:
# Smoking
# No     5.522039
# Yes    5.473625
# Name: Severity of Anxiety Attack (1-10), dtype: float64

# %% [markdown]
# this gives the avg of severity of heart attack patients with respect to smoking.
