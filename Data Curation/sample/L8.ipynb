# %%
import pandas as pd
import random
data = pd.read_csv("loan.csv")

# %%
sample = data.sample(5 , replace = True)
sample
# Out:
#     ID  Age  Income  Credit_Score  Loan_Approved
# 19  20   24   29000           610              0
# 19  20   24   29000           610              0
# 7    8   38   65000           680              0
# 3    4   28   35000           600              0
# 7    8   38   65000           680              0

# %%
sample = data.sample(5 , replace = False)
sample
# Out:
#     ID  Age  Income  Credit_Score  Loan_Approved
# 13  14   39   70000           730              0
# 16  17   30   45000           680              0
# 11  12   41   75000           740              1
# 12  13   35   60000           710              0
# 3    4   28   35000           600              0

# %%
systematic_sample = data.iloc[::4]
systematic_sample
# Out:
#     ID  Age  Income  Credit_Score  Loan_Approved
# 0    1   25   30000           650              0
# 4    5   50  120000           800              1
# 8    9   48   90000           780              1
# 12  13   35   60000           710              0
# 16  17   30   45000           680              0

# %%
cluster_sample = data[data["Credit_Score"] >= 750]
cluster_sample
# Out:
#     ID  Age  Income  Credit_Score  Loan_Approved
# 2    3   45   80000           750              1
# 4    5   50  120000           800              1
# 8    9   48   90000           780              1
# 15  16   52  150000           850              1
# 18  19   42   78000           750              1

# %%
cluster_sample = data[(data["Credit_Score"] >= 650) & (data["Credit_Score"] <= 749)]
cluster_sample
# Out:
#     ID  Age  Income  Credit_Score  Loan_Approved
# 0    1   25   30000           650              0
# 1    2   32   50000           700              0
# 5    6   29   40000           670              0
# 6    7   33   55000           720              0
# 7    8   38   65000           680              0
# 9   10   31   48000           690              0
# 11  12   41   75000           740              1
# 12  13   35   60000           710              0
# 13  14   39   70000           730              0
# 16  17   30   45000           680              0
# 17  18   36   62000           700              0

# %%
cluster_sample = data[data["Credit_Score"] < 750]
cluster_sample
# Out:
#     ID  Age  Income  Credit_Score  Loan_Approved
# 0    1   25   30000           650              0
# 1    2   32   50000           700              0
# 3    4   28   35000           600              0
# 5    6   29   40000           670              0
# 6    7   33   55000           720              0
# 7    8   38   65000           680              0
# 9   10   31   48000           690              0
# 10  11   27   32000           620              0
# 11  12   41   75000           740              1
# 12  13   35   60000           710              0
# 13  14   39   70000           730              0
# 14  15   26   31000           640              0
# 16  17   30   45000           680              0
# 17  18   36   62000           700              0
# 19  20   24   29000           610              0

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %%
print("Class Distribution:", Counter(data["Loan_Approved"]))
# Out:
# Original Class Distribution: Counter({0: 14, 1: 6})

# %%
X = data.drop(columns=["Loan_Approved", "ID"])
y = data["Loan_Approved"]

# %%
oversampler = RandomOverSampler(random_state=42)
X_over, y_over = oversampler.fit_resample(X, y)
print("Random Oversampling:", Counter(y_over))
# Out:
# Random Oversampling: Counter({0: 14, 1: 14})

# %%
undersampler = RandomUnderSampler(random_state=42)
X_under, y_under = undersampler.fit_resample(X, y)
print("Random Undersampling:", Counter(y_under))
# Out:
# Random Undersampling: Counter({0: 6, 1: 6})

# %%
smote = SMOTE(random_state=42)
X_smote, y_smote = smote.fit_resample(X, y)
print("SMOTE:", Counter(y_smote))
# Out:
# SMOTE: Counter({0: 14, 1: 14})
